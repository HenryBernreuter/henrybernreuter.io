# %% [markdown]
# Unoffical Transcripts
# Henry Bernreuter
# Georgia State University
# Expected Graduation Fall '19

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
transcripts = "C:\\Users\\new user\\Downloads\\transcript.csv"
df = pd.read_csv(transcripts)
print(df)
# Out:
#                               Class Grade  HoursAtt  Quality Points  \
# 0             ENGLISH COMPOSITION I     A       3.0            12.0
# 1                FIRST-YEAR SEMINAR     A       3.0            12.0
# 2            ENGLISH COMPOSITION II     B       3.0             9.0
# 3              SURVEY OF WORLD HIST     A       3.0            12.0
# 4                  CHOICES FOR LIFE     A       1.0             4.0
# 5               AMERICAN GOVERNMENT     A       3.0            12.0
# 6      INTRO. TO GENERAL PSYCHOLOGY     A       3.0            12.0
# 7                WORLD LITERATURE I     A       3.0            12.0
# 8     PERSONAL AND COMMUNITY HEALTH     B       3.0             9.0
# 9          UNITED STATES HISTORY II     A       4.0            12.0
# 10                  PUBLIC SPEAKING     F       3.0             0.0
# 11                  COLLEGE ALGEBRA     F       3.0             4.0
# 12                  COLLEGE ALGEBRA     A       3.0            12.0
# ...

# %%
for col in df.columns: 
    print(col)
# Out:
# Class
# Grade
# HoursAtt
# Quality Points
# Semester
# HourRec
# GPA

# %%
print(df.sort_values('Quality Points', ascending=False))
# Out:
#                               Class Grade  HoursAtt  Quality Points  \
# 44                           TOTALS   NaN     139.0           357.4
# 45                              NaN   NaN       NaN           227.4
# 32    DESIGNING IMMERSIVE MEDIA EXP    A+       4.0            17.2
# 27               DATA VISUALIZATION     A       4.0            16.0
# 23     PRINCIPLES OF COMPUTER SCI I    B+       4.0            13.2
# 12                  COLLEGE ALGEBRA     A       3.0            12.0
# 35     INTRO TO WEATHER AND CLIMATE     B       4.0            12.0
# 33                  MEDIA ANALYTICS     A       3.0            12.0
# 1                FIRST-YEAR SEMINAR     A       3.0            12.0
# 18            INTRO GAME INDUSTRIES     A       3.0            12.0
# 15         INTRO TO WORLD RELIGIONS     A       3.0            12.0
# 0             ENGLISH COMPOSITION I     A       3.0            12.0
# 6      INTRO. TO GENERAL PSYCHOLOGY     A       3.0            12.0
# ...

# %%
g = sns.PairGrid(df, vars=['HoursAtt', 'Grade', 'HourRec', 'Quality Points'],
                 hue='GPA', palette='RdBu_r')
g.map(plt.scatter, alpha=1)
g.add_legend();

# %%
d1 = df.interpolate(method ='linear', limit_direction ='forward') 
d1
# Out:
#                               Class Grade  HoursAtt  Quality Points  \
# 0             ENGLISH COMPOSITION I     A       3.0           12.00
# 1                FIRST-YEAR SEMINAR     A       3.0           12.00
# 2            ENGLISH COMPOSITION II     B       3.0            9.00
# 3              SURVEY OF WORLD HIST     A       3.0           12.00
# 4                  CHOICES FOR LIFE     A       1.0            4.00
# 5               AMERICAN GOVERNMENT     A       3.0           12.00
# 6      INTRO. TO GENERAL PSYCHOLOGY     A       3.0           12.00
# 7                WORLD LITERATURE I     A       3.0           12.00
# 8     PERSONAL AND COMMUNITY HEALTH     B       3.0            9.00
# 9          UNITED STATES HISTORY II     A       4.0           12.00
# 10                  PUBLIC SPEAKING     F       3.0            0.00
# 11                  COLLEGE ALGEBRA     F       3.0            4.00
# 12                  COLLEGE ALGEBRA     A       3.0           12.00
# ...

# %%
x = df1.Semester
y = df1.GPA
fig = plt.figure(figsize = (15, 10))
ax = plt.axes()
ax.plot(x, y,)
ax.set(xlabel='Semester', ylabel='GPA',
       title='GPA Time Analysis');

# %%
analytics = [df.iloc[12], df.iloc[23], df.iloc[26], df.iloc[27], df.iloc[28], df.iloc[31], df.iloc[33], df.iloc[36]]
df2 = pd.DataFrame(analytics) 
df2
# Out:
#                            Class Grade  HoursAtt  Quality Points    Semester  \
# 12               COLLEGE ALGEBRA     A       3.0            12.0  Spring2016
# 23  PRINCIPLES OF COMPUTER SCI I    B+       4.0            13.2  Spring2018
# 26         INTRO TO INFO SYSTEMS     B       3.0             9.0  Summer2018
# 27            DATA VISUALIZATION     A       4.0            16.0  Summer2018
# 28   INTRODUCTION TO PROGRAMMING     A       3.0            11.1    Fall2018
# 31         ELEMENTARY STATISTICS    A-       3.0            11.1    Fall2018
# 33               MEDIA ANALYTICS     A       3.0            12.0  Spring2019
# 36                   PRECALCULUS    B+       3.0             9.9  Spring2019
#
#     HourRec   GPA
# 12      4.0  4.00
# 23      3.3   NaN
# 26      3.0   NaN
# 27      4.0  3.57
# 28      3.7   NaN
# 31      3.7  3.20
# 33      4.0   NaN
# 36      3.3   NaN

# %%
df4 = df2[['HourRec']].copy()
analytics_gpa = df4.mean()
total_gpa = df.iloc[44]['GPA']
analytics_gpa
#total_gpa
# Out:
# HourRec    3.625
# dtype: float64

# %%
objects = ('Analytics GPA', 'Overall GPA')
y_pos = np.arange(len(objects))
performance = [3.625,3.22]
fig = plt.figure(figsize = (10.5, 5))
plt.bar(y_pos, performance, align='center', alpha=0.85, color='b',)
plt.xticks(y_pos, objects)
plt.ylabel('GPA')
plt.title('GPA of Analytical Classes Vs Overall GPA')

plt.show()

analytics = [df.iloc[12], df.iloc[23], df.iloc[26], df.iloc[27], df.iloc[28], df.iloc[31], df.iloc[33], df.iloc[36]]
df2 = pd.DataFrame(analytics) 
df2
# Out:
#                            Class Grade  HoursAtt  Quality Points    Semester  \
# 12               COLLEGE ALGEBRA     A       3.0            12.0  Spring2016
# 23  PRINCIPLES OF COMPUTER SCI I    B+       4.0            13.2  Spring2018
# 26         INTRO TO INFO SYSTEMS     B       3.0             9.0  Summer2018
# 27            DATA VISUALIZATION     A       4.0            16.0  Summer2018
# 28   INTRODUCTION TO PROGRAMMING     A       3.0            11.1    Fall2018
# 31         ELEMENTARY STATISTICS    A-       3.0            11.1    Fall2018
# 33               MEDIA ANALYTICS     A       3.0            12.0  Spring2019
# 36                   PRECALCULUS    B+       3.0             9.9  Spring2019
#
#     HourRec   GPA
# 12      4.0  4.00
# 23      3.3   NaN
# 26      3.0   NaN
# 27      4.0  3.57
# 28      3.7   NaN
# 31      3.7  3.20
# 33      4.0   NaN
# 36      3.3   NaN

# %%
More work better grades.

# %%
n_groups = 2
means_frank = (3.22)
means_guido = (3.65)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, means_frank, bar_width,
alpha=opacity,
color='b',
label='Frank')

rects2 = plt.bar(index + bar_width, means_guido, bar_width,
alpha=opacity,
color='g',
label='Guido')

plt.xlabel('Person')
plt.ylabel('Scores')
plt.title('Scores by person')
plt.xticks(index + bar_width, ('A', 'B', 'C', 'D'))
plt.legend()

plt.tight_layout()
plt.show()
